# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.16.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.7.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\programdata\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2024.2.2)
# Downloading folium-0.16.0-py2.py3-none-any.whl (100 kB)
#    ---------------------------------------- 0.0/100.0 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/100.0 kB ? eta -:--:--
#    ------------------- ------------------- 51.2/100.0 kB 871.5 kB/s eta 0:00:01
#    ---------------------------------------- 100.0/100.0 kB 1.1 MB/s eta 0:00:00
# Downloading branca-0.7.1-py3-none-any.whl (25 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.7.1 folium-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import folium
import geopandas as gpd

# %%
location = "https://data.smartdublin.ie/dataset/33ec9fe2-4957-4e9a-ab55-c5e917c7a9ab/resource/2dec86ed-76ed-47a3-ae28-646db5c5b965/download/dublin.csv"
bike_station_locations = pd.read_csv(location)

# %%
bike_station_locations
# Out:
#      Number                    Name                 Address   Latitude  \
# 0        42        SMITHFIELD NORTH        Smithfield North  53.349562
# 1        30    PARNELL SQUARE NORTH    Parnell Square North  53.353462
# 2        54          CLONMEL STREET          Clonmel Street  53.336021
# 3       108           AVONDALE ROAD           Avondale Road  53.359405
# 4        56      MOUNT STREET LOWER      Mount Street Lower  53.337960
# ..      ...                     ...                     ...        ...
# 105      39          WILTON TERRACE          Wilton Terrace  53.332383
# 106      83              EMMET ROAD              Emmet Road  53.340714
# 107      92  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)  53.347802
# 108      21   LEINSTER STREET SOUTH   Leinster Street South  53.342180
# 109      88         BLACKHALL PLACE         Blackhall Place  53.348800
#
#      Longitude
# 0    -6.278198
# 1    -6.265305
# 2    -6.262980
# 3    -6.276142
# 4    -6.241530
# ..         ...
# 105  -6.252717
# 106  -6.308191
# 107  -6.292432
# 108  -6.254485
# 109  -6.281637
#
# [110 rows x 5 columns]

# %%
bike_station_locations = bike_station_locations[["Latitude", "Longitude", "Name"]]

# %%
bike_station_locations
# Out:
#       Latitude  Longitude                    Name
# 0    53.349562  -6.278198        SMITHFIELD NORTH
# 1    53.353462  -6.265305    PARNELL SQUARE NORTH
# 2    53.336021  -6.262980          CLONMEL STREET
# 3    53.359405  -6.276142           AVONDALE ROAD
# 4    53.337960  -6.241530      MOUNT STREET LOWER
# ..         ...        ...                     ...
# 105  53.332383  -6.252717          WILTON TERRACE
# 106  53.340714  -6.308191              EMMET ROAD
# 107  53.347802  -6.292432  HEUSTON BRIDGE (NORTH)
# 108  53.342180  -6.254485   LEINSTER STREET SOUTH
# 109  53.348800  -6.281637         BLACKHALL PLACE
#
# [110 rows x 3 columns]

# %%
map = folium.Map(location=[bike_station_locations.Latitude.mean(), bike_station_locations.Longitude.mean()], zoom_start=14, control_scale=True)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28ce7090e14ed0c121d3386efe903cb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28ce7090e14ed0c121d3386efe903cb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28ce7090e14ed0c121d3386efe903cb7 = L.map(
#                 &quot;map_28ce7090e14ed0c121d3386efe903cb7&quot;,
#                 {
#                     center: [53.34549189090908, -6.264740490909091],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_28ce7090e14ed0c121d3386efe903cb7);
#
#
#
#
#
#             var tile_layer_7e002e30758f88407cd1319bb991ddd0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7e002e30758f88407cd1319bb991ddd0.addTo(map_28ce7090e14ed0c121d3386efe903cb7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#cargar puntos en mapa
for index, location_info in bike_station_locations.iterrows():
    folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Name"]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28ce7090e14ed0c121d3386efe903cb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28ce7090e14ed0c121d3386efe903cb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28ce7090e14ed0c121d3386efe903cb7 = L.map(
#                 &quot;map_28ce7090e14ed0c121d3386efe903cb7&quot;,
#                 {
#                     center: [53.34549189090908, -6.264740490909091],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_28ce7090e14ed0c121d3386efe903cb7);
#
#
#
#
#
#             var tile_layer_7e002e30758f88407cd1319bb991ddd0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7e002e30758f88407cd1319bb991ddd0.addTo(map_28ce7090e14ed0c121d3386efe903cb7);
#
#
#             tile_layer_7e002e30758f88407cd1319bb991ddd0.addTo(map_28ce7090e14ed0c121d3386efe903cb7);
#
#
#             var marker_5259b202835ece977d2fc7e2aa25e5d2 = L.marker(
#                 [53.349562, -6.278198],
#                 {}
#             ).addTo(map_28ce7090e14ed0c121d3386efe903cb7);
#
#
#         var popup_7754748fcd42b346dfd630da6e74b31b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9a9d51968eb8cee97aa49e52c6421d9 = $(`&lt;div id=&quot;html_d9a9d51968eb8cee97aa49e52c6421d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SMITHFIELD NORTH&lt;/div&gt;`)[0];
#                 popup_7754748fcd42b346dfd630da6e74b31b.setContent(html_d9a9d51968eb8cee97aa49e52c6421d9);
#
#
#
#         marker_5259b202835ece977d2fc7e2aa25e5d2.bindPopup(popup_7754748fcd42b346dfd630da6e74b31b)
#         ;
#
#
#
#
#             var marker_d4feed335986edbeb9f52fbf2ba94984 = L.marker(
#                 [53.353462, -6.265305],
#                 {}
#             ).addTo(map_28ce7090e14ed0c121d3386efe903cb7);
#
#
#         var popup_eee188cf20e29d42a7cc86a7464f63c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_006b08b36d64ff115520b4c2853242e8 = $(`&lt;div id=&quot;html_006b08b36d64ff115520b4c2853242e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PARNELL SQUARE NORTH&lt;/div&gt;`)[0];
#                 popup_eee188cf20e29d42a7cc86a7464f63c1.setContent(html_006b08b36d64ff115520b4c2853242e8);
#
#
#
#         marker_d4feed335986edbeb9f52fbf2ba94984.bindPopup(popup_eee188cf20e29d42a7cc86a7464f63c1)
#         ;
#
#
#
#
#             var marker_171707453b04869fbe54d744a7297f89 = L.marker(
#                 [53.336021, -6.26298],
#                 {}
#             ).addTo(map_28ce7090e14ed0c121d3386efe903cb7);
#
#
#         var popup_e369ee677aa080238f8dcfc52b8fc639 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56fb32119bffb41fca655f5ed4351a17 = $(`&lt;div id=&quot;html_56fb32119bffb41fca655f5ed4351a17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CLONMEL STREET&lt;/div&gt;`)[0];
#                 popup_e369ee677aa080238f8dcfc52b8fc639.setContent(html_56fb32119bffb41fca655f5ed4351a17);
#
#
#
#         marker_171707453b04869fbe54d744a7297f89.bindPopup(popup_e369ee677aa080238f8dcfc52b8fc639)
#         ;
#
#
#
#
#             var marker_5a7f642ad8a6ff03483d8326d89a44af = L.marker(
#                 [53.359405, -6.276142],
#                 {}
#             ).addTo(map_28ce7090e14ed0c121d3386efe903cb7);
#
#
#         var popup_3728ca3f3a72ef2e26e13e3156d953c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d72cc357ec534608c4ee1edb662f0c79 = $(`&lt;div id=&quot;html_d72cc357ec534608c4ee1edb662f0c79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AVONDALE ROAD&lt;/div&gt;`)[0];
#                 popup_3728ca3f3a72ef2e26e13e3156d953c5.setContent(html_d72cc357ec534608c4ee1edb662f0c79);
#
#
#
#         marker_5a7f642ad8a6ff03483d8326d89a44af.bindPopup(popup_3728ca3f3a72ef2e26e13e3156d953c5)
#         ;
#
#
#
#
#             var marker_d8297df635992f6428a8adf2d1c05ed9 = L.marker(
#                 [53.33796, -6.24153],
#                 {}
#             ).addTo(map_28ce7090e14ed0c121d3386efe903cb7);
#
#
#         var popup_c4a07a1c72fa90e67fadeb2098fbebfc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a4da6568e647c7a20f6a489cd73d14a = $(`&lt;div id=&quot;html_9a4da6568e647c7a20f6a489cd73d14a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MOUNT STREET LOWER&lt;/div&gt;`)[0];
#                 popup_c4a07a1c72fa90e67fadeb2098fbebfc.setContent(html_9a4da6568e647c7a20f6a489cd73d14a);
#
#
#
#         marker_d8297df635992f6428a8adf2d1c05ed9.bindPopup(popup_c4a07a1c72fa90e67fadeb2098fbebfc)
